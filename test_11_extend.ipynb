# %%
import requests
import datetime
import pandas as pd

DIM_CAMPAIGN_REPORT = "ym:s:date,ym:s:<attribution>UTMCampaign"
METR_CAMPAIGN_REPORT = "ym:s:visits,ym:s:users,ym:s:ecommercePurchases,ym:s:ecommerce<currency>ConvertedRevenue"

YM_ED_COUNTER_ID = "89127076"
FILTER_ED_CAMPAIGN = "ym:s:<attribution>UTMCampaign=~'.*_ed_.*' AND NOT(ym:s:<attribution>UTMCampaign=~'.*(blogg|smm_|emall|edostavka).*')"


YM_TOKEN = "y0_AgAAAABaPiH5AAoGKAAAAADk-0IaNKLrObttQOOgBjtexDD_-vF8Nys"

at_start_date = "2023-10-1"
at_end_date = "2023-10-18"

dt_today = datetime.date.today()
dt_yesterday = str(dt_today - datetime.timedelta(days=20))




def request_ym_data():
        # параметры запроса
        params = {
            "dimensions": DIM_CAMPAIGN_REPORT,
            "metrics": METR_CAMPAIGN_REPORT,
            "ids": YM_ED_COUNTER_ID,
            "date1": at_start_date,
            "date2": at_end_date,
            # ym:s:deviceCategory!='mobile'
            "filters": FILTER_ED_CAMPAIGN,
            "accuracy": 1,
            "limit": 100000,
            "offset": 1,
            "pretty": False,
        }

        # Формируем URL для выполнения запроса
        try:
            url = "https://api-metrika.yandex.net/stat/v1/data?"

            # Отправляем запрос к API
            headers = {"Authorization": f"OAuth {YM_TOKEN}"}
            response = requests.get(url, headers=headers, params=params)
            # Обрабатываем результаты
            if response.status_code != 200:
                print(
                    "Произошла ошибка при выполнении запроса:",
                    f"{response.status_code}",
                    f"{response.text}",
                )
                exit()
            else:
                data = response
                return data
                at_total_rows = data["total_rows"]
                at_ym_data = data
                if self.at_total_rows == 0:
                    print("Произошла ошибка при выполнении запроса: Пустое тело ответа")
                    exit()
                return data, self.at_total_rows
        except Exception as e:
            raise e

# %%
a = request_ym_data()
js = a.json()
js["query"]
# Out:
# {'ids': [89127076],
#  'dimensions': ['ym:s:date', 'ym:s:lastSignUTMCampaign'],
#  'metrics': ['ym:s:visits',
#   'ym:s:users',
#   'ym:s:ecommercePurchases',
#   'ym:s:ecommerceBYNConvertedRevenue'],
#  'sort': ['-ym:s:visits'],
#  'date1': '2023-10-01',
#  'date2': '2023-10-18',
#  'filters': "ym:s:LastSignUTMCampaign=~'.*_ed_.*' AND NOT(ym:s:LastSignUTMCampaign=~'.*(blogg|smm_|emall|edostavka).*')",
#  'limit': 100000,
#  'offset': 1,
#  'group': 'Week',
#  'auto_group_size': '1',
#  'attr_name': '',
#  'quantile': '50',
#  'offline_window': '21',
#  'attribution': 'LastSign',
#  'currency': 'BYN',
#  'adfox_event_id': '0'}

# %%
js["query"]["dimensions"]
# Out:
# ['ym:s:date', 'ym:s:lastSignUTMCampaign']

# %%
js["query"]["metrics"]
# Out:
# ['ym:s:visits',
#  'ym:s:users',
#  'ym:s:ecommercePurchases',
#  'ym:s:ecommerceBYNConvertedRevenue']

# %%
data = js["data"]
for i in data:
    print(i)
# Out:
# {'dimensions': [{'name': '2023-10-05'}, {'name': 'ed_ed_dostavka_produktov_look_a_like_rb_google_pmax'}], 'metrics': [1788.0, 1256.0, 150.0, 17127.569993]}
# {'dimensions': [{'name': '2023-10-09'}, {'name': 'ed_ed_dostavka_produktov_look_a_like_rb_google_pmax'}], 'metrics': [1722.0, 1212.0, 109.0, 10835.769991]}
# {'dimensions': [{'name': '2023-10-06'}, {'name': 'ed_ed_dostavka_produktov_look_a_like_rb_google_pmax'}], 'metrics': [
0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_dostavka_produktov_keyword_minsk_google_pmax'}], 'metrics': [26.0, 13.0, 3.0, 218.509999]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_dostavka_produktov_keyword_regions_google_pmax'}], 'metrics': [26.0, 18.0, 4.0, 576.57]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_dostavka_produktov_keyword_minsk_google_pmax'}], 'metrics': [26.0, 14.0, 5.0, 603.079999]}
# {'dimensions': [{'name': '2023-10-05'}, {'name': 'ed_ed_dostavka_produktov_keyword_minsk_google_pmax'}], 'metrics': [25.0, 17.0, 3.0, 281.2]}
# {'dimensions': [{'name': '2023-10-06'}, {'name': 'ed_ed_dostavka_produktov_keyword_regions_google_pmax'}], 'metrics': [25.0, 20.0, 4.0, 436.19]}
# {'dimensions': [{'name': '2023-10-07'}, {'name': 'ed_ed_dostavka_produktov_keyword_regions_google_pmax'}], 'metrics': [25.0, 20.0, 4.0, 335.02]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_dostavka_produktov_keyword_minsk_google_pmax'}], 'metrics': [25.0, 16.0, 4.0, 588.76]}
# {'dimensions': [{'name': '2023-10-02'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [24.0, 20.0, 6.0, 597.059999]}
# {'dimensions': [{'name': '2023-10-07'}, {'name': 'ed_ed_super_fresh_target_rb_inst'}], 'metrics': [24.0, 23.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_1_1_minsk_inst'}], 'metrics': [24.0, 24.0, 1.0, 46.65]}
# {'dimensions': [{'name': '2023-10-09'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [23.0, 16.0, 2.0, 261.63]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_dostavka_produktov_keyword_regions_google_pmax'}], 'metrics': [23.0, 18.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-08'}, {'name': 'ed_ed_crush_5_target_minsk_inst'}], 'metrics': [22.0, 22.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-01'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [21.0, 13.0, 6.0, 986.47]}
# {'dimensions': [{'name': '2023-10-05'}, {'name': 'ed_ed_crush_5_target_minsk_inst'}], 'metrics': [21.0, 20.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-06'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [21.0, 14.0, 5.0, 807.979999]}
# {'dimensions': [{'name': '2023-10-10'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [21.0, 11.0, 3.0, 415.51]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [21.0, 16.0, 3.0, 486.889999]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_dostavka_produktov_keyword_regions_google_pmax'}], 'metrics': [21.0, 9.0, 4.0, 408.05]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [21.0, 17.0, 4.0, 582.63]}
# {'dimensions': [{'name': '2023-10-03'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [20.0, 14.0, 4.0, 494.579999]}
# {'dimensions': [{'name': '2023-10-04'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [20.0, 13.0, 5.0, 712.17]}
# {'dimensions': [{'name': '2023-10-09'}, {'name': 'ed_ed_dostavka_produktov_keyword_regions_google_pmax'}], 'metrics': [20.0, 16.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_dostavka_produktov_keyword_regions_google_pmax'}], 'metrics': [20.0, 17.0, 1.0, 146.25]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_crush_target_minsk_inst'}], 'metrics': [19.0, 19.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [19.0, 14.0, 5.0, 389.48]}
# {'dimensions': [{'name': '2023-10-08'}, {'name': 'ed_ed_competitors_rb_google_search'}], 'metrics': [18.0, 11.0, 3.0, 297.049999]}
# {'dimensions': [{'name': '2023-10-08'}, {'name': 'ed_ed_dostavka_produktov_rb_google_pmax_new_banner_keyword'}], 'metrics': [18.0, 16.0, 5.0, 650.33]}
# ...
# {'dimensions': [{'name': '2023-10-10'}, {'name': 'ed_ed_dodo_pizza_rb_site'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-10'}, {'name': 'ed_ed_dostavka_produktov_minsk_yandex_search_keyword'}], 'metrics': [1.0, 1.0, 1.0, 71.83]}
# {'dimensions': [{'name': '2023-10-10'}, {'name': 'ed_ed_mi_vernulis_vitebsk_google_YT'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-10'}, {'name': 'ed_ed_rastiajka_skidka2procenta_rb_e-dostavka.by'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-10'}, {'name': 'ed_ed_smartphone_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-10'}, {'name': 'ed_ed_svetlaya_pyatnica_minsk_google_pmax'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-10'}, {'name': 'ler_ed_article_vitbichi.by'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-10'}, {'name': 'wg_ed_sverhnizkie_tseny_rb_yandex_search_dynamic'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_coffee_tea_minsk_yandex_tovarnaya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_crush_4_target_minsk_inst'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_detskie_igrushki_rb_google_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_detskie_podguzniki_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_dostavka_produktov_gomel_google_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_mudrosti_minsk_inst'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_new_5_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_podarochnye_nabory_rb_vk'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'ed_ed_smartphone_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'wg_ed_bolsche_chem_dostavka_produktov_august2022_rb_google_discovery'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'wg_ed_plity_gefest_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'wg_ed_smartphone_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-11'}, {'name': 'wg_ed_tehnika_electronika_rb_yandex_smart_banners'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_coffee_tea_minsk_yandex_tovarnaya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_crush_4_target_minsk_inst'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_detskie_igrushki_rb_google_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_detskie_podguzniki_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_dodo_pizza_rb_site'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_dostavka_produktov_all_regions_new_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_dostavka_produktov_competitors_rb_google_pmax'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_smartphone_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_supertseny_main_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'ed_ed_vegan_minsk_google_merchant'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'wg_ed_detskie_igrushki_rb_yandex_search_keyword'}], 'metrics': [1.0, 1.0, 1.0, 280.85]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'wg_ed_detskoye_pitanie_rb_google_search_keyword'}], 'metrics': [1.0, 1.0, 1.0, 151.5]}
# {'dimensions': [{'name': '2023-10-12'}, {'name': 'wg_ed_stiralnye_mashiny_rb_google_kms_discovery'}], 'metrics': [1.0, 1.0, 1.0, 88.19]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_8_march_minsk_tiktok'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_black_friday_11_minsk_inst'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_detskie_tovary_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 1.0, 101.54]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_detskoye_pitanie_keyword_rb_google_pmax'}], 'metrics': [1.0, 1.0, 1.0, 82.1]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_dodo_pizza_rb_site'}], 'metrics': [1.0, 1.0, 1.0, 253.13]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_dostavka_productov_rb_google_kms_amo_banner_discovery_new_remarketing'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_dostavka_produktov_competitors_rb_google_pmax'}], 'metrics': [1.0, 1.0, 1.0, 90.51]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_igrushki_rb_google_merchant'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_new_5_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_piknik_minsk_google_merchant'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_school_minsk_yandex_tovarnaya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ed_ed_wowcena_minsk_google_merchant'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'ler_ed_article_gorodvitebsk.by'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'wg_ed_bolsche_chem_dostavka_produktov_august2022_rb_google_discovery'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'wg_ed_detskoye_pitanie_rb_google_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'wg_ed_plity_gefest_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-13'}, {'name': 'wg_ed_smartphone_rb_yandex_search'}], 'metrics': [1.0, 1.0, 1.0, 88.3]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_coffee_tea_minsk_google_merchant'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_crush_5_target_minsk_inst'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_detskie_podguzniki_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_dostavka_productov_rb_google_kms_amo_banner_discovery_new_remarketing'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_dostavka_produktov_all_regions_new_yandex_search'}], 'metrics': [1.0, 1.0, 1.0, 56.309999]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_dostavka_produktov_minsk_google_search_keyword'}], 'metrics': [1.0, 1.0, 1.0, 88.35]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_mi_vernulis_gomel_google_YT'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_mudrosti_minsk_inst'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_smartphone_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'ed_ed_vegan_minsk_google_merchant'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-14'}, {'name': 'wg_ed_tehnika_electronika_rb_yandex_smart_banners'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_black_friday_minsk_inst'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_detskie_igrushki_keyword_rb_google_pmax'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_detskie_podguzniki_keyword_rb_google_pmax'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_detskie_tovary_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_dostavka_produktov_minsk_yandex_search_keyword'}], 'metrics': [1.0, 1.0, 1.0, 95.94]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_piknik_minsk_google_merchant'}], 'metrics': [1.0, 1.0, 1.0, 186.82]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_podarochnye_nabory_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_supertseny_main_new_rb_google_discovery'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_teсhnika_electronika_rb_yandex_smart_banners'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ed_ed_wowcena_minsk_google_discovery'}], 'metrics': [1.0, 1.0, 1.0, 78.29]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ler_ed_article_belkagomel.by'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'ler_ed_article_vitebsk.biz'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'wg_ed_detskie_igrushki_rb_google_search_keyword'}], 'metrics': [1.0, 1.0, 1.0, 110.73]}
# {'dimensions': [{'name': '2023-10-15'}, {'name': 'wg_ed_detskie_podguzniki_rb_google_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_coffee_tea_minsk_yandex_tovarnaya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_crush_4_target_minsk_inst'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_detskie_igrushki_keyword_rb_google_pmax'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_detskie_igrushki_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_detskie_tovary_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_dostavka_produktov_gomel_google_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_dostavka_produktov_regions_google_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_piknik_minsk_google_merchant'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_podarochnye_nabory_rb_vk'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_school_minsk_yandex_tovarnaya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_smartphone_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_supertseny_main_new_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_wowcena_minsk_google_discovery'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_wowcena_minsk_google_merchant'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ed_ed_wowcena_minsk_yandex_smart_banners'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'ler_ed_article_belkagomel.by'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'wg_ed_chernaia_piatnica_november2022_rb_tiktok'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-16'}, {'name': 'wg_ed_detskie_podguzniki_rb_google_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_coffee_tea_minsk_yandex_tovarnaya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_detskie_podguzniki_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_dostavka_produktov_all_regions_new_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_dostavka_produktov_minsk_google_search_keyword'}], 'metrics': [1.0, 1.0, 1.0, 99.669999]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_dostavka_produktov_minsk_yandex_search_keyword'}], 'metrics': [1.0, 1.0, 1.0, 61.82]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_new_5_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_podarochnye_nabory_rb_vk'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_rastiajka_skidka2procenta_rb_e-dostavka.by'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_smartphone_rb_yandex_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_supertseny_main_new_rb_google_kms'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_supertseny_main_rb_google_kms'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_svetlaya_pyatnica_minsk_google_pmax'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ed_ed_wowcena_minsk_google_merchant'}], 'metrics': [1.0, 1.0, 1.0, 105.84]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'ler_ed_article_belkagomel.by'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'wg_ed_bolsche_chem_dostavka_produktov_august2022_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'wg_ed_detskie_igrushki_rb_yandex_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'wg_ed_detskoye_pitanie_rb_google_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-17'}, {'name': 'wg_ed_pylesosy_brand_rb_google_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_competitors_rb_google_search'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_detskie_igrushki_keyword_rb_google_pmax'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_detskoye_pitanie_keyword_rb_google_pmax'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_dostavka_produktov_all_regions_new_yandex_search'}], 'metrics': [1.0, 1.0, 1.0, 62.83]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_dostavka_produktov_regions_google_search_keyword'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_mi_vernulis_gomel_google_YT'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_podarochnye_nabory_rb_yandex_search'}], 'metrics': [1.0, 1.0, 1.0, 264.779999]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_wowcena_minsk_google_discovery'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'ed_ed_wowcena_minsk_yandex_smart_banners'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'wg_ed_bolsche_chem_dostavka_produktov_august2022_rb_google_discovery'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'wg_ed_chernaia_piatnica_november2022_rb_tiktok'}], 'metrics': [1.0, 1.0, 0.0, 0.0]}
# {'dimensions': [{'name': '2023-10-18'}, {'name': 'wg_ed_smart_banners_elektronika_rb_yandex_rsya'}], 'metrics': [1.0, 1.0, 1.0, 182.25]}

# %%
def transform_ym_response_to_df(js):
    dimensions = js["query"]["dimensions"]
    metrics = js["query"]["metrics"]
    rows = js["data"]
    rows_data = []
    for row in rows:
        dimensions_values = [dim["name"] for dim in row["dimensions"]]
        metrics_values = row["metrics"]
        row_data = dimensions_values + metrics_values
        rows_data.append(row_data)
    df = pd.DataFrame(rows_data, columns=dimensions + metrics)
    return df

# %%
transform_ym_response_to_df(js)
# Out:
#       ym:s:date                           ym:s:lastSignUTMCampaign  \
# 0    2023-10-05  ed_ed_dostavka_produktov_look_a_like_rb_google...
# 1    2023-10-09  ed_ed_dostavka_produktov_look_a_like_rb_google...
# 2    2023-10-06  ed_ed_dostavka_produktov_look_a_like_rb_google...
# 3    2023-10-04  ed_ed_dostavka_produktov_look_a_like_rb_google...
# 4    2023-10-11  ed_ed_dostavka_produktov_look_a_like_rb_google...
# ..          ...                                                ...
# 926  2023-10-18               ed_ed_wowcena_minsk_google_discovery
# 927  2023-10-18           ed_ed_wowcena_minsk_yandex_smart_banners
# 928  2023-10-18  wg_ed_bolsche_chem_dostavka_produktov_august20...
# 929  2023-10-18     wg_ed_chernaia_piatnica_november2022_rb_tiktok
# 930  2023-10-18     wg_ed_smart_banners_elektronika_rb_yandex_rsya
#
#      ym:s:visits  ym:s:users  ym:s:ecommercePurchases  \
# 0         1788.0      1256.0                    150.0
# 1         1722.0      1212.0                    109.0
# 2         1706.0      1170.0                    142.0
# 3         1698.0      1145.0                    108.0
# 4         1697.0      1196.0                    125.0
# ..           ...         ...                      ...
# 926          1.0         1.0                      0.0
# 927          1.0         1.0                      0.0
# 928          1.0         1.0                      0.0
# 929          1.0         1.0                      0.0
# 930          1.0         1.0                      1.0
#
#      ym:s:ecommerceBYNConvertedRevenue
# 0                         17127.569993
# 1                         10835.769991
# 2                         16087.989993
# 3                         11246.359989
# 4                         13798.169984
# ..                                 ...
# 926                           0.000000
# 927                           0.000000
# 928                           0.000000
# 929                           0.000000
# 930                         182.250000
#
# [931 rows x 6 columns]
